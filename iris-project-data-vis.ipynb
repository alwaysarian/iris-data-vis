# %%
import pandas as pd

# %%
import warnings 
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="white", color_codes=True)

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris["PetalWidthCm"].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.5    12
# 1.8    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.3     7
# 0.4     7
# 0.1     6
# 2.0     6
# 2.1     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: PetalWidthCm, dtype: int64

# %%
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")

# %%
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris, size=7)

# %%
sns.FacetGrid(iris, hue="Species", size=5,palette="RdBu_d") \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
  .add_legend()

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=iris,palette="Blues")

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris,palette="Blues")
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris,palette="Blues_d", jitter=True, edgecolor="gray")

# %%
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris,palette="Blues", size=6)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris,palette="Blues_d", jitter=True)

# %%
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species",palette="Greens", size=3)

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3, diag_kind="kde")

# %%
iris.drop("Id", axis=1).boxplot(by="Species", figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BC3DF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001BF29898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001C2D4278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001C3BC7F0>]], dtype=object)

# %%
from pandas.tools.plotting import andrews_curves
andrews_curves(iris.drop("Id", axis=1), "Species")

# %%
from pandas.tools.plotting import parallel_coordinates
parallel_coordinates(iris.drop("Id", axis=1), "Species")

# %%
from pandas.tools.plotting import radviz
radviz(iris.drop("Id", axis=1), "Species")
